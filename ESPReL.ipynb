# %%
import zipfile
import requests
import os
import pandas as pd

# %%
url = 'https://opendata.nrct.go.th/dataset/9ab557d2-3476-4a67-aa50-114e21abe0b5/resource/1a8a7992-4092-4085-824d-c052eb6859d2/download/organizations-that-have-been-registered-laboratories-2-uv2fty.zip'
file = 'esprel.zip'

response = requests.get(url)

with open(file, 'wb') as f:
    f.write(response.content)

# %%
dir_path = os.getcwd()

# %%
with zipfile.ZipFile('esprel.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
list = os.listdir(dir_path)
print(list)
# Out:
# ['.config', 'esprel.zip', 'datapackage.json', 'hnwyngaanthiiaidrabkaarkhuenthaebiiynh-ngptibatikaar-pracchampii-2565-apedtkh-muulaitrmaasthii-3.csv', 'sample_data']

# %%
name = 'hnwyngaanthiiaidrabkaarkhuenthaebiiynh-ngptibatikaar-pracchampii-2565-apedtkh-muulaitrmaasthii-3.csv'

# %%
df = pd.read_csv(name)

# %%
df.head(5)
# Out:
#         1              2                    3  \
# 0  row_no      \n lab_id          \n lab_name
# 1   ลำดับ     เลขทะเบียน  ชื่อห้องปฏิบัติการ
# 2       1  2-0010-0171-1             ห้อง 709
# 3       2  2-0010-0145-2             ห้อง 708
# 4       3  2-0010-0499-1             ห้อง 707
#
#                                    4                          5  \
# 0                         \nlab_name                 org_name 1
# 1             ผู้ดูแลห้องปฏิบัติการ   ฝ่าย/กลุ่ม/สาขา/ส่วน/ห้อง
# 2                ผศ.ดร.รัฐ พิชญางกูร                        NaN
# 3  รองศาสตราจารย์ ดร.ธีรพงษ์ บัวบูชา                        NaN
# 4          ผศ.ดร.กนกทิพย์ ภักดีบำรุง                        NaN
#
#                                6                       7  \
# 0                     org_name 2              org_name 3
# 1  ภาค/แผนก/หลักสูตร/กอง/โครงการ  สำนัก/คณะ/ศูนย์/อุทยาน
# 2                 ภาควิชาชีวเคมี          คณะวิทยาศาสตร์
# 3                 ภาควิชาชีวเคมี          คณะวิทยาศาสตร์
# 4                 ภาควิชาชีวเคมี          คณะวิทยาศาสตร์
#
#                                  8           9                     10
# 0                       org_name 4  org_name 5             org_name 6
# 1  สถาบัน/วิทยาลัย/โรงบาล/โรงเรียน    วิทยาเขต            มหาวิทยาลัย
# 2                              NaN         NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 3                              NaN         NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 4                              NaN         NaN  จุฬาลงกรณ์มหาวิทยาลัย

# %%
df = pd.read_csv(name, skiprows=2, header=0)
df.head(5)
# Out:
#    ลำดับ     เลขทะเบียน ชื่อห้องปฏิบัติการ   \
# 0      1  2-0010-0171-1            ห้อง 709
# 1      2  2-0010-0145-2            ห้อง 708
# 2      3  2-0010-0499-1            ห้อง 707
# 3      4  2-0010-0148-7          ห้อง 617/3
# 4      5  2-0010-0498-2            ห้อง 618
#
#                     ผู้ดูแลห้องปฏิบัติการ  ฝ่าย/กลุ่ม/สาขา/ส่วน/ห้อง  \
# 0                      ผศ.ดร.รัฐ พิชญางกูร                       NaN
# 1        รองศาสตราจารย์ ดร.ธีรพงษ์ บัวบูชา                       NaN
# 2                ผศ.ดร.กนกทิพย์ ภักดีบำรุง                       NaN
# 3  รองศาสตราจารย์ ดร.  ธนะกาญจน์ มัญชุพาณี                       NaN
# 4                     อ.ดร.ภาวินี แป้นเพชร                       NaN
#
#   ภาค/แผนก/หลักสูตร/กอง/โครงการ สำนัก/คณะ/ศูนย์/อุทยาน  \
# 0                ภาควิชาชีวเคมี         คณะวิทยาศาสตร์
# 1                ภาควิชาชีวเคมี         คณะวิทยาศาสตร์
# 2                ภาควิชาชีวเคมี         คณะวิทยาศาสตร์
# 3                ภาควิชาชีวเคมี         คณะวิทยาศาสตร์
# 4                ภาควิชาชีวเคมี         คณะวิทยาศาสตร์
#
#   สถาบัน/วิทยาลัย/โรงบาล/โรงเรียน วิทยาเขต            มหาวิทยาลัย
# 0                             NaN      NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 1                             NaN      NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 2                             NaN      NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 3                             NaN      NaN  จุฬาลงกรณ์มหาวิทยาลัย
# 4                             NaN      NaN  จุฬาลงกรณ์มหาวิทยาลัย

# %%
rama_lab = df[df.apply(lambda row: row.astype(str).str.contains('รามา', case=False).any(), axis=1)]
rama_lab
# Out:
#       ลำดับ     เลขทะเบียน                                ชื่อห้องปฏิบัติการ   \
# 111     112  2-0130-0316-1  3D in vitro Organ Models and Regenerative Medi...
# 820     821  2-0130-0040-5    Neurodegenerative Disease and Neuroregeneration
# 865     866  2-0130-0330-7                                       Pharmacology
# 1318   1319  2-0130-0322-6                            กายวิภาคศาสตร์ทางคลินิก
# 1382   1383  2-0130-0106-1                          เคมีคลินิก (ห้อง RECEM 2)
# 1582   1583  2-0130-0080-4                                         ชีวโมเลกุล
# 2340   2341  2-0130-0011-1                       หน่วยชีวเคมีและเคมีวิเคราะห์
# 2382   2383  2-0130-0338-2                            หน่วยพยาธิวิทยากายวิภาค
# 2808   2809  2-0130-0077-4                        ห้องปฏิบัติการ Cell culture
# 2816   2817  2-0130-0323-4                      ห้องปฏิบัติการ Drug discovery
# 2838   2839  2-0130-0318-8  ห้องปฏิบัติการ Microbiology (Microbiology Clus...
# 2947   2948  2-0130-0240-8                       ห้องปฏิบัติการกลาง พรีคลินิก
# 3487   3488  2-0130-0076-6                          ห้องปฏิบัติการจุลชีววิทยา
# 3740   3741  2-0130-0035-9                       ห้องปฏิบัติการเซลล์ต้นกำเนิด
#
#                               ผู้ดูแลห้องปฏิบัติการ   \
# 111                 ดร.ภกญ.พิมลรัตน์ เกตุสวัสดิ์สมคร
# 820   รองศาสตราจารย์ ดร.นายแพทย์เพิ่มพันธุ์ ธรรมสโรช
# 865                      รศ.ดร.ภญ.พรพรรณ วิวิธนาภรณ์
# 1318                             ดร.เบญริตา  จิตอารี
# 1382                                  อารีพร สังฆกุล
# 1582                       สุวรรณี ชั้นประเสริฐโยธิน
# 2340                               ไพศาล   จิตธรธรรม
# 2382                                   อานนท์ สมพงษ์
# 2808                                  ศุภนาถ ศรีศาลา
# 2816       รองศาสตราจารย์ ดร.นพ.ฉัตรชัย เหมือนประสาท
# 2838                       ดร.นพ.พิสุทธิ์ พงษ์ชัยกุล
# 2947                        ดร. นพ. นิธิ อัศวภาณุมาศ
# 3487                                  ทัศนีย์ โล้หนู
# 3740                             ณรงค์ฤทธิ์  ศรีแก้ว
#
#      ฝ่าย/กลุ่ม/สาขา/ส่วน/ห้อง ภาค/แผนก/หลักสูตร/กอง/โครงการ  \
# 111                        NaN                           NaN
# 820              สาขาพรีคลินิก                           NaN
# 865              สาขาพรีคลินิก                           NaN
# 1318             สาขาพรีคลินิก                           NaN
# 1382                       NaN             ภาควิชาพยาธิวิทยา
# 1582                       NaN                           NaN
# 2340                       NaN                           NaN
# 2382   หน่วยพยาธิวิทยากายวิภาค                           NaN
# 2808                       NaN                           NaN
# 2816                       NaN                           NaN
# 2838             สาขาพรีคลินิก                           NaN
# 2947                       NaN                           NaN
# 3487                       NaN                           NaN
# 3740                       NaN                           NaN
#
#                สำนัก/คณะ/ศูนย์/อุทยาน สถาบัน/วิทยาลัย/โรงบาล/โรงเรียน  \
# 111   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 820   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 865   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 1318  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 1382  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 1582  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 2340  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 2382  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2808  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 2816  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2838  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2947  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 3487  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 3740  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
#
#                  วิทยาเขต       มหาวิทยาลัย
# 111   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 820   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 865   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 1318  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 1382        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 1582        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 2340        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 2382                  NaN               NaN
# 2808        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 2816  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 2838  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 2947  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 3487        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 3740        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล

# %%
rama_lab.shape
# Out:
# (14, 10)

# %%
rama_lab.columns
# Out:
# Index(['ลำดับ', 'เลขทะเบียน', 'ชื่อห้องปฏิบัติการ ', 'ผู้ดูแลห้องปฏิบัติการ ',
#        'ฝ่าย/กลุ่ม/สาขา/ส่วน/ห้อง', 'ภาค/แผนก/หลักสูตร/กอง/โครงการ',
#        'สำนัก/คณะ/ศูนย์/อุทยาน', 'สถาบัน/วิทยาลัย/โรงบาล/โรงเรียน', 'วิทยาเขต',
#        'มหาวิทยาลัย'],
#       dtype='object')

# %%
rama_lab = rama_lab.sort_values('เลขทะเบียน', ascending=True)

# %%
rama_lab
# Out:
#       ลำดับ     เลขทะเบียน                                ชื่อห้องปฏิบัติการ   \
# 2340   2341  2-0130-0011-1                       หน่วยชีวเคมีและเคมีวิเคราะห์
# 3740   3741  2-0130-0035-9                       ห้องปฏิบัติการเซลล์ต้นกำเนิด
# 820     821  2-0130-0040-5    Neurodegenerative Disease and Neuroregeneration
# 3487   3488  2-0130-0076-6                          ห้องปฏิบัติการจุลชีววิทยา
# 2808   2809  2-0130-0077-4                        ห้องปฏิบัติการ Cell culture
# 1582   1583  2-0130-0080-4                                         ชีวโมเลกุล
# 1382   1383  2-0130-0106-1                          เคมีคลินิก (ห้อง RECEM 2)
# 2947   2948  2-0130-0240-8                       ห้องปฏิบัติการกลาง พรีคลินิก
# 111     112  2-0130-0316-1  3D in vitro Organ Models and Regenerative Medi...
# 2838   2839  2-0130-0318-8  ห้องปฏิบัติการ Microbiology (Microbiology Clus...
# 1318   1319  2-0130-0322-6                            กายวิภาคศาสตร์ทางคลินิก
# 2816   2817  2-0130-0323-4                      ห้องปฏิบัติการ Drug discovery
# 865     866  2-0130-0330-7                                       Pharmacology
# 2382   2383  2-0130-0338-2                            หน่วยพยาธิวิทยากายวิภาค
#
#                               ผู้ดูแลห้องปฏิบัติการ   \
# 2340                               ไพศาล   จิตธรธรรม
# 3740                             ณรงค์ฤทธิ์  ศรีแก้ว
# 820   รองศาสตราจารย์ ดร.นายแพทย์เพิ่มพันธุ์ ธรรมสโรช
# 3487                                  ทัศนีย์ โล้หนู
# 2808                                  ศุภนาถ ศรีศาลา
# 1582                       สุวรรณี ชั้นประเสริฐโยธิน
# 1382                                  อารีพร สังฆกุล
# 2947                        ดร. นพ. นิธิ อัศวภาณุมาศ
# 111                 ดร.ภกญ.พิมลรัตน์ เกตุสวัสดิ์สมคร
# 2838                       ดร.นพ.พิสุทธิ์ พงษ์ชัยกุล
# 1318                             ดร.เบญริตา  จิตอารี
# 2816       รองศาสตราจารย์ ดร.นพ.ฉัตรชัย เหมือนประสาท
# 865                      รศ.ดร.ภญ.พรพรรณ วิวิธนาภรณ์
# 2382                                   อานนท์ สมพงษ์
#
#      ฝ่าย/กลุ่ม/สาขา/ส่วน/ห้อง ภาค/แผนก/หลักสูตร/กอง/โครงการ  \
# 2340                       NaN                           NaN
# 3740                       NaN                           NaN
# 820              สาขาพรีคลินิก                           NaN
# 3487                       NaN                           NaN
# 2808                       NaN                           NaN
# 1582                       NaN                           NaN
# 1382                       NaN             ภาควิชาพยาธิวิทยา
# 2947                       NaN                           NaN
# 111                        NaN                           NaN
# 2838             สาขาพรีคลินิก                           NaN
# 1318             สาขาพรีคลินิก                           NaN
# 2816                       NaN                           NaN
# 865              สาขาพรีคลินิก                           NaN
# 2382   หน่วยพยาธิวิทยากายวิภาค                           NaN
#
#                สำนัก/คณะ/ศูนย์/อุทยาน สถาบัน/วิทยาลัย/โรงบาล/โรงเรียน  \
# 2340  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 3740  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 820   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 3487  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 2808  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 1582  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 1382  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี                             NaN
# 2947  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 111   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2838  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 1318  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2816  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 865   คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
# 2382  คณะแพทยศาสตร์โรงพยาบาลรามาธิบดี    สถาบันการแพทย์จักรีนฤบดินทร์
#
#                  วิทยาเขต       มหาวิทยาลัย
# 2340        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 3740        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 820   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 3487        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 2808        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 1582        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 1382        วิทยาเขตพญาไท  มหาวิทยาลัยมหิดล
# 2947  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 111   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 2838  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 1318  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 2816  วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 865   วิทยาเขตสมุทรปราการ  มหาวิทยาลัยมหิดล
# 2382                  NaN               NaN

# %%
rama_lab.to_csv('rama_lab_esprel.csv', index =False)
