# %% [markdown]
# <a href="https://colab.research.google.com/github/tlerksuthirat/lab_management/blob/main/Budget_2568.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
# Out:
# --2024-07-10 04:59:06--  https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Phonbopit/sarabun-webfont/master/fonts/thsarabunnew-webfont.ttf [following]
# --2024-07-10 04:59:06--  https://raw.githubusercontent.com/Phonbopit/sarabun-webfont/master/fonts/thsarabunnew-webfont.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98308 (96K) [application/octet-stream]
# Saving to: ‘thsarabunnew-webfont.ttf’
#
# thsarabunnew-webfon 100%[===================>]  96.00K  --.-KB/s    in 0.01s
#
# 2024-07-10 04:59:06 (7.73 MB/s) - ‘thsarabunnew-webfont.ttf’ saved [98308/98308]

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)
import pandas as pd
import matplotlib as plt
plt.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf') # 3.2+
plt.rc('font', family='TH Sarabun New')

# %%
published_url = 'https://docs.google.com/spreadsheets/d/1_gqyl1IDwNXvTKkqQU6hPW7wLvRoljzLjpPsN2llZek/edit?fbclid=IwZXh0bgNhZW0CMTAAAR1udOuN_6BpsvILoz3g6EIPa7ypf8PbdAyDBzMIurRfuaU4aNvG1uj8Nmw_aem_9FiK8R8XnBiyYQ2K-Laebw&gid=1392569138#gid=1392569138'

# %%
sheet_id = published_url.split('/')[-2]  # Extract sheet ID from URL
sheet = gc.open_by_key(sheet_id)

# %%
sheet
# Out:
# <Spreadsheet "[68] Thailand's Budget" id:1_gqyl1IDwNXvTKkqQU6hPW7wLvRoljzLjpPsN2llZek>

# %%
# Get a list of all worksheets
worksheet_list = sheet.worksheets()

# %%
# Print the titles of all worksheets
for worksheet in worksheet_list:
    print(worksheet.title)
# Out:
# README
# Data dict
# 2024-06-15
# กระทบยอด (ตามกระทรวง)
# หน่วยงานหลัก-ย่อย
# ขาว-แดง (ตามกระทรวง)
# ขาว-เหลือง (2024-06-21)
# แผนงาน

# %%
# Choose a specific worksheet if needed (default is the first sheet)
worksheet = sheet.get_worksheet(2)

# %%
# Get all values from the worksheet
data = worksheet.get_all_values()

# %%
import csv
with open('budget.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(data)

# %%
df = pd.read_csv('budget.csv')
df.head()
# Out:
# <ipython-input-36-311e5cef0ffd>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('budget.csv')
#                                              REF_DOC  REF_PAGE_NO MINISTRY  \
# 0  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            2   งบกลาง
# 1  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            2   งบกลาง
# 2  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            2   งบกลาง
# 3  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            2   งบกลาง
# 4  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            2   งบกลาง
#
#   BUDGETARY_UNIT                                        BUDGET_PLAN  \
# 0         งบกลาง                        แผนงานพื้นฐานด้านความมั่นคง
# 1         งบกลาง       แผนงานบริหารเพื่อรองรับกรณีฉุกเฉินหรือจำเป็น
# 2         งบกลาง  แผนงานยุทธศาสตร์พัฒนาระบบการเตรียมพร้อมแห่งชาต...
# 3         งบกลาง             แผนงานยุทธศาสตร์เสริมสร้างพลังทางสังคม
# 4         งบกลาง            แผนงานยุทธศาสตร์สร้างหลักประกันทางสังคม
#
#   CROSS_FUNC? OUTPUT PROJECT CATEGORY_LV1 CATEGORY_LV2 CATEGORY_LV3  \
# 0       False    NaN     NaN          NaN          NaN          NaN
# 1       False    NaN     NaN          NaN          NaN          NaN
# 2       False    NaN     NaN          NaN          NaN          NaN
# 3       False    NaN     NaN          NaN          NaN          NaN
# 4       False    NaN     NaN          NaN          NaN          NaN
#
#   CATEGORY_LV4 CATEGORY_LV5 CATEGORY_LV6  \
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
#                                     ITEM_DESCRIPTION          AMOUNT  \
# 0  ค่าใช้จ่ายเกี่ยวกับการเสด็จพระราชดำเนินและต้อน...   1,000,000,000
# 1                        เงินชดเชยค่างานสิ่งก่อสร้าง     800,000,000
# 2  ค่าใช้จ่ายชดใช้เงินทดรองราชการเพื่อช่วยเหลือผู...   4,000,000,000
# 3       ค่าใช้จ่ายตามโครงการอันเนื่องมาจากพระราชดำริ   2,500,000,000
# 4  ค่าใช้จ่ายในการรักษาพยาบาลข้าราชการ ลูกจ้าง แล...  93,800,000,000
#
#    FISCAL_YEAR  OBLIGED?
# 0         2025     False
# 1         2025     False
# 2         2025     False
# 3         2025     False
# 4         2025     False

# %%
unique_ministries = df['MINISTRY'].unique()
print(unique_ministries)
# Out:
# ['งบกลาง' 'กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม' 'กระทรวงพลังงาน'
#  'กระทรวงยุติธรรม' 'กระทรวงวัฒนธรรม' 'กระทรวงมหาดไทย' 'สำนักนายกรัฐมนตรี'
#  'หน่วยงานของรัฐสภา' 'กระทรวงการท่องเที่ยวและกีฬา' 'หน่วยงานของศาล'
#  'กระทรวงแรงงาน' 'สภากาชาดไทย' 'กระทรวงคมนาคม' 'กระทรวงการคลัง'
#  'กระทรวงการต่างประเทศ' 'กระทรวงการพัฒนาสังคมและความมั่นคงของมนุษย์'
#  'กระทรวงเกษตรและสหกรณ์'
#  'กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม' 'รัฐวิสาหกิจ'
#  'กระทรวงพาณิชย์' 'กระทรวงอุตสาหกรรม'
#  'ส่วนราชการไม่สังกัดสำนักนายกรัฐมนตรีฯ' 'กระทรวงสาธารณสุข'
#  'กระทรวงกลาโหม' 'กระทรวงศึกษาธิการ' 'หน่วยงานอื่นของรัฐ'
#  'ส่วนราชการในพระองค์' 'หน่วยงานขององค์กรอิสระและองค์กรอัยการ'
#  'ทุนหมุนเวียน' 'กระทรวงดิจิทัลเพื่อเศรษฐกิจและสังคม'
#  'จังหวัดและกลุ่มจังหวัด' 'องค์กรปกครองส่วนท้องถิ่น']

# %%
filtered_df = df[df['MINISTRY'] == 'กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม']
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['REF_DOC', 'REF_PAGE_NO', 'MINISTRY', 'BUDGETARY_UNIT', 'BUDGET_PLAN', 'CROSS_FUNC?', 'OUTPUT', 'PROJECT', 'CATEGORY_LV1', 'CATEGORY_LV2', 'CATEGORY_LV3', 'CATEGORY_LV4', 'CATEGORY_LV5', 'CATEGORY_LV6', 'ITEM_DESCRIPTION', 'AMOUNT', 'FISCAL_YEAR', 'OBLIGED?']

# %%
unique_unit = filtered_df['BUDGETARY_UNIT'].unique()
print(unique_unit)
# Out:
# ['มหาวิทยาลัยนเรศวร' 'มหาวิทยาลัยอุบลราชธานี' 'มหาวิทยาลัยราชภัฏเทพสตรี'
#  'มหาวิทยาลัยราชภัฏจันทรเกษม'
#  'สำนักปลัดกระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม'
#  'กรมวิทยาศาสตร์บริการ' 'สำนักงานการวิจัยแห่งชาติ'
#  'สำนักงานปรมาณูเพื่อสันติ' 'มหาวิทยาลัยรามคำแหง'
#  'มหาวิทยาลัยสุโขทัยธรรมาธิราช' 'มหาวิทยาลัยมหาสารคาม'
#  'มหาวิทยาลัยกาฬสินธุ์' 'มหาวิทยาลัยนราธิวาสราชนครินทร์'
#  'มหาวิทยาลัยนครพนม' 'สถาบันวิทยาลัยชุมชน' 'มหาวิทยาลัยราชภัฏเชียงราย'
#  'มหาวิทยาลัยราชภัฏเชียงใหม่' 'มหาวิทยาลัยราชภัฏกำแพงเพชร'
#  'มหาวิทยาลัยราชภัฏกาญจนบุรี' 'มหาวิทยาลัยราชภัฏชัยภูมิ'
#  'มหาวิทยาลัยราชภัฏภูเก็ต' 'มหาวิทยาลัยราชภัฏธนบุรี'
#  'มหาวิทยาลัยราชภัฏพระนคร' 'มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา'
#  'มหาวิทยาลัยราชภัฏราชนครินทร์' 'มหาวิทยาลัยราชภัฏลำปาง'
#  'มหาวิทยาลัยราชภัฏนครสวรรค์' 'มหาวิทยาลัยราชภัฏพิบูลสงคราม'
#  'มหาวิทยาลัยราชภัฏเพชรบูรณ์' 'มหาวิทยาลัยราชภัฏมหาสารคาม'
#  'มหาวิทยาลัยราชภัฏเลย' 'มหาวิทยาลัยราชภัฏสกลนคร'
#  'มหาวิทยาลัยราชภัฏนครราชสีมา' 'มหาวิทยาลัยราชภัฏบุรีรัมย์'
#  'มหาวิทยาลัยราชภัฏพระนครศรีอยุธยา'
#  'มหาวิทยาลัยราชภัฏวไลยอลงกรณ์ ในพระบรมราชูปถัมภ์ จังหวัดปทุมธานี'
#  'มหาวิทยาลัยราชภัฏรำไพพรรณี' 'มหาวิทยาลัยราชภัฏนครปฐม'
#  'มหาวิทยาลัยราชภัฏเพชรบุรี' 'มหาวิทยาลัยราชภัฏนครศรีธรรมราช'
#  'มหาวิทยาลัยราชภัฏร้อยเอ็ด' 'มหาวิทยาลัยราชภัฏศรีสะเกษ'
#  'มหาวิทยาลัยราชภัฏอุตรดิตถ์' 'มหาวิทยาลัยราชภัฏอุดรธานี'
#  'มหาวิทยาลัยราชภัฏอุบลราชธานี' 'มหาวิทยาลัยราชภัฏหมู่บ้านจอมบึง'
#  'มหาวิทยาลัยราชภัฏสงขลา' 'มหาวิทยาลัยราชภัฏสุราษฎร์ธานี'
#  'มหาวิทยาลัยราชภัฏสวนสุนันทา' 'มหาวิทยาลัยเทคโนโลยีราชมงคลธัญบุรี'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลกรุงเทพ'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลตะวันออก' 'มหาวิทยาลัยเทคโนโลยีราชมงคลพระนคร'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลล้านนา' 'มหาวิทยาลัยเทคโนโลยีราชมงคลศรีวิชัย'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลสุวรรณภูมิ'
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลอีสาน' 'จุฬาลงกรณ์มหาวิทยาลัย'
#  'มหาวิทยาลัยเกษตรศาสตร์' 'มหาวิทยาลัยขอนแก่น' 'มหาวิทยาลัยทักษิณ'
#  'สถาบันดนตรีกัลยาณิวัฒนา' 'มหาวิทยาลัยแม่ฟ้าหลวง' 'มหาวิทยาลัยมหิดล'
#  'มหาวิทยาลัยสงขลานครินทร์' 'สถาบันบัณฑิตพัฒนบริหารศาสตร์'
#  'มหาวิทยาลัยเทคโนโลยีสุรนารี' 'มหาวิทยาลัยแม่โจ้'
#  'สถาบันมาตรวิทยาแห่งชาติ' 'มหาวิทยาลัยธรรมศาสตร์'
#  'สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง'
#  'มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ' 'มหาวิทยาลัยพะเยา'
#  'มหาวิทยาลัยวลัยลักษณ์' 'มหาวิทยาลัยมหามกุฏราชวิทยาลัย'
#  'มหาวิทยาลัยมหาจุฬาลงกรณราชวิทยาลัย' 'มหาวิทยาลัยบูรพา'
#  'มหาวิทยาลัยสวนดุสิต' 'มหาวิทยาลัยศิลปากร' 'มหาวิทยาลัยศรีนครินทรวิโรฒ'
#  'สถาบันการพยาบาลศรีสวรินทิรา สภากาชาดไทย' 'สถาบันเทคโนโลยีจิตรลดา'
#  'สำนักงานพัฒนาเทคโนโลยีอวกาศและภูมิสารสนเทศ (องค์การมหาชน)'
#  'สถาบันเทคโนโลยีนิวเคลียร์แห่งชาติ (องค์การมหาชน)'
#  'สถาบันวิจัยแสงซินโครตรอน (องค์การมหาชน)'
#  'สถาบันวิจัยดาราศาสตร์แห่งชาติ (องค์การมหาชน)'
#  'สำนักงานนวัตกรรมแห่งชาติ (องค์การมหาชน)'
#  'ศูนย์ความเป็นเลิศด้านชีววิทยาศาสตร์ (องค์กรมหาชน)'
#  'สถาบันสารสนเทศทรัพยากรน้ำ (องค์กรมหาชน)'
#  'สำนักงานพัฒนาวิทยาศาสตร์และเทคโนโลยีแห่งชาติ'
#  'สํานักงานสภานโยบายการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรมแห่งชาติ'
#  'สถาบันเทคโนโลยีปทุมวัน' 'มหาวิทยาลัยราชภัฏยะลา'
#  'มหาวิทยาลัยราชภัฏสุรินทร์' 'มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี'
#  'สำนักงานคณะกรรมการส่งเสริมวิทยาศาสตร์ วิจัยและนวัตกรรม'
#  'มหาวิทยาลัยเชียงใหม่']

# %%
filtered_df1 = filtered_df[filtered_df['BUDGETARY_UNIT'] == 'มหาวิทยาลัยมหิดล']
filtered_df1.head(10)
# Out:
#                                                  REF_DOC  REF_PAGE_NO  \
# 33860  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33861  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33862  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33863  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33864  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33865  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            7
# 33866  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            7
# 33867  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            7
# 33868  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            7
# 33869  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            7
#
#                                                MINISTRY    BUDGETARY_UNIT  \
# 33860  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33861  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33862  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33863  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33864  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33865  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33866  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33867  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33868  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33869  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
#
#                                              BUDGET_PLAN CROSS_FUNC?  \
# 33860                                แผนงานบุคลากรภาครัฐ       False
# 33861                                แผนงานบุคลากรภาครัฐ       False
# 33862                                แผนงานบุคลากรภาครัฐ       False
# 33863                                แผนงานบุคลากรภาครัฐ       False
# 33864                                แผนงานบุคลากรภาครัฐ       False
# 33865  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...       False
# 33866  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...       False
# 33867  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...       False
# 33868  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...       False
# 33869  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...       False
#
#                          OUTPUT PROJECT   CATEGORY_LV1  \
# 33860                       NaN     NaN      งบบุคลากร
# 33861                       NaN     NaN      งบบุคลากร
# 33862                       NaN     NaN      งบบุคลากร
# 33863                       NaN     NaN  งบเงินอุดหนุน
# 33864                       NaN     NaN  งบเงินอุดหนุน
# 33865  ผลงานการให้บริการวิชาการ     NaN  งบเงินอุดหนุน
# 33866  ผลงานการให้บริการวิชาการ     NaN  งบเงินอุดหนุน
# 33867  ผลงานการให้บริการวิชาการ     NaN  งบเงินอุดหนุน
# 33868  ผลงานการให้บริการวิชาการ     NaN  งบเงินอุดหนุน
# 33869  ผลงานการให้บริการวิชาการ     NaN  งบเงินอุดหนุน
#
#                    CATEGORY_LV2 CATEGORY_LV3 CATEGORY_LV4 CATEGORY_LV5  \
# 33860  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
# 33861  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
# 33862                       NaN          NaN          NaN          NaN
# 33863         เงินอุดหนุนทั่วไป          NaN          NaN          NaN
# 33864         เงินอุดหนุนทั่วไป          NaN          NaN          NaN
# 33865         เงินอุดหนุนทั่วไป          NaN          NaN          NaN
# 33866         เงินอุดหนุนทั่วไป  ค่าครุภัณฑ์          NaN          NaN
# 33867         เงินอุดหนุนทั่วไป  ค่าครุภัณฑ์          NaN          NaN
# 33868         เงินอุดหนุนทั่วไป  ค่าครุภัณฑ์          NaN          NaN
# 33869         เงินอุดหนุนทั่วไป  ค่าครุภัณฑ์          NaN          NaN
#
#       CATEGORY_LV6                                   ITEM_DESCRIPTION  \
# 33860          NaN                                          เงินเดือน
# 33861          NaN                                       ค่าจ้างประจำ
# 33862          NaN                                    ค่าจ้างชั่วคราว
# 33863          NaN                          ค่าจ้างพนักงานมหาวิทยาลัย
# 33864          NaN                                ค่าใช้จ่ายดำเนินงาน
# 33865          NaN                                ค่าใช้จ่ายดำเนินงาน
# 33866          NaN  ครุภัณฑ์การศึกษาที่มีราคาต่อหน่วยต่ำกว่า 1 ล้า...
# 33867          NaN  เครื่องกรองแยกสารและทำเข้มข้นผลิตภัณฑ์ ตำบลศาล...
# 33868          NaN  เครื่องตรวจอวัยวะภายในด้วยคลื่นแม่เหล็กไฟฟ้า ข...
# 33869          NaN  เครื่องอบฆ่าเชื้อด้วยระบบไฮโดรเจนเปอร์ออกไซด์พ...
#
#               AMOUNT  FISCAL_YEAR  OBLIGED?
# 33860    325,801,400         2025     False
# 33861    128,738,200         2025     False
# 33862     37,316,700         2025     False
# 33863  9,937,299,500         2025     False
# 33864     97,672,800         2025     False
# 33865      3,277,500         2025     False
# 33866      9,510,300         2025     False
# 33867      2,940,000         2025     False
# 33868     40,000,000         2025     False
# 33869      2,782,000         2025     False

# %%
filtered_df1.to_csv('budget_mu.csv', index=False)

# %%
filtered_df1.to_excel('budget_mu.xlsx', index=False)

# %%
unique_item = filtered_df1['BUDGET_PLAN'].unique()
print(unique_item)
# Out:
# ['แผนงานบุคลากรภาครัฐ'
#  'แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพทรัพยากรมนุษย์'
#  'แผนงานยุทธศาสตร์พัฒนาศักยภาพคนตลอดช่วงชีวิต'
#  'แผนงานยุทธศาสตร์เสริมสร้างให้คนมีสุขภาวะที่ดี'
#  'แผนงานยุทธศาสตร์สร้างความเสมอภาคทางการศึกษา']

# %%
# Remove commas and convert to numeric
filtered_df1['NUMBER_AMOUNT'] = (
    df['AMOUNT']
    .astype(str)  # Ensure the column is treated as strings
    .str.replace(',', '', regex=False)  # Remove commas
    .str.replace(' ', '', regex=True) # remove whitespace
    .apply(pd.to_numeric, errors='coerce')  # Convert to numeric, handle errors
)
# Out:
# <ipython-input-64-1acedb20cd95>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df1['NUMBER_AMOUNT'] = (

# %%
filtered_df1.head(2)
# Out:
#                                                  REF_DOC  REF_PAGE_NO  \
# 33860  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33861  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
#
#                                                MINISTRY    BUDGETARY_UNIT  \
# 33860  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33861  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
#
#                BUDGET_PLAN CROSS_FUNC? OUTPUT PROJECT CATEGORY_LV1  \
# 33860  แผนงานบุคลากรภาครัฐ       False    NaN     NaN    งบบุคลากร
# 33861  แผนงานบุคลากรภาครัฐ       False    NaN     NaN    งบบุคลากร
#
#                    CATEGORY_LV2 CATEGORY_LV3 CATEGORY_LV4 CATEGORY_LV5  \
# 33860  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
# 33861  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
#
#       CATEGORY_LV6 ITEM_DESCRIPTION       AMOUNT  FISCAL_YEAR  OBLIGED?  \
# 33860          NaN        เงินเดือน  325,801,400         2025     False
# 33861          NaN     ค่าจ้างประจำ  128,738,200         2025     False
#
#        NUMBER_AMOUNT
# 33860      325801400
# 33861      128738200

# %%
sum = filtered_df1['NUMBER_AMOUNT'].sum()
# Display the sum in scientific notation
print(f"{sum:,}")
print(f"{sum:.2e}")
# Out:
# 22,466,789,000
# 2.25e+10

# %%
#List of budget plans to filter
target_budget_plans = ['แผนงานบุคลากรภาครัฐ', 'แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพทรัพยากรมนุษย์', 'แผนงานยุทธศาสตร์พัฒนาศักยภาพคนตลอดช่วงชีวิต', 'แผนงานยุทธศาสตร์เสริมสร้างให้คนมีสุขภาวะที่ดี', 'แผนงานยุทธศาสตร์สร้างความเสมอภาคทางการศึกษา']

# Filter the DataFrame
filtered_df2 = filtered_df1[filtered_df1['BUDGET_PLAN'].isin(target_budget_plans)]

# %%
sum = filtered_df2['NUMBER_AMOUNT'].sum()
print(f"{sum:,}")
print(f"{sum:.2e}")
# Out:
# 22,466,789,000
# 2.25e+10

# %%
# Group by 'BUDGET_PLAN' and calculate the sum
grouped_data = filtered_df2.groupby('BUDGET_PLAN')['NUMBER_AMOUNT'].sum()

# Create a new DataFrame
result_df = grouped_data.reset_index(name='TOTAL_AMOUNT')
print(result_df)
result_df.to_excel('budget_mu_group.xlsx', index=False)
# Out:
#                                          BUDGET_PLAN  TOTAL_AMOUNT
# 0                                แผนงานบุคลากรภาครัฐ   10526828600
# 1  แผนงานพื้นฐานด้านการพัฒนาและเสริมสร้างศักยภาพท...     338563200
# 2        แผนงานยุทธศาสตร์พัฒนาศักยภาพคนตลอดช่วงชีวิต    1608119000
# 3        แผนงานยุทธศาสตร์สร้างความเสมอภาคทางการศึกษา       2969700
# 4      แผนงานยุทธศาสตร์เสริมสร้างให้คนมีสุขภาวะที่ดี    9990308500

# %%
# Create pile chart
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'TH Sarabun New'  # Or another Thai-compatible font
plt.figure(figsize=(8, 6))
plt.pie(result_df['TOTAL_AMOUNT'], labels=result_df['BUDGET_PLAN'], autopct='%1.1f%%', startangle=140)
plt.title('Budget Plan Distribution')
plt.axis('equal')
plt.show()  # Display the pie chart

# %%
filtered_df3 = filtered_df2[filtered_df2['BUDGET_PLAN'] == 'แผนงานบุคลากรภาครัฐ']
filtered_df3.head(2)
# Out:
#                                                  REF_DOC  REF_PAGE_NO  \
# 33860  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
# 33861  ./ฉบับร่างพระราชบัญญัติงบประมาณรายจ่าย (ร่าง พ...            5
#
#                                                MINISTRY    BUDGETARY_UNIT  \
# 33860  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
# 33861  กระทรวงการอุดมศึกษา วิทยาศาสตร์ วิจัยและนวัตกรรม  มหาวิทยาลัยมหิดล
#
#                BUDGET_PLAN CROSS_FUNC? OUTPUT PROJECT CATEGORY_LV1  \
# 33860  แผนงานบุคลากรภาครัฐ       False    NaN     NaN    งบบุคลากร
# 33861  แผนงานบุคลากรภาครัฐ       False    NaN     NaN    งบบุคลากร
#
#                    CATEGORY_LV2 CATEGORY_LV3 CATEGORY_LV4 CATEGORY_LV5  \
# 33860  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
# 33861  เงินเดือนและค่าจ้างประจำ          NaN          NaN          NaN
#
#       CATEGORY_LV6 ITEM_DESCRIPTION       AMOUNT  FISCAL_YEAR  OBLIGED?  \
# 33860          NaN        เงินเดือน  325,801,400         2025     False
# 33861          NaN     ค่าจ้างประจำ  128,738,200         2025     False
#
#        NUMBER_AMOUNT
# 33860      325801400
# 33861      128738200

# %%
unique_HC = filtered_df3['ITEM_DESCRIPTION'].unique()
print(unique_HC)
# Out:
# ['เงินเดือน' 'ค่าจ้างประจำ' 'ค่าจ้างชั่วคราว' 'ค่าจ้างพนักงานมหาวิทยาลัย'
#  'ค่าใช้จ่ายดำเนินงาน']

# %%
columns_to_print = ['BUDGETARY_UNIT','BUDGET_PLAN','ITEM_DESCRIPTION', 'NUMBER_AMOUNT']  # List of column names you want
print(filtered_df3[columns_to_print])
# Out:
#          BUDGETARY_UNIT          BUDGET_PLAN           ITEM_DESCRIPTION  \
# 33860  มหาวิทยาลัยมหิดล  แผนงานบุคลากรภาครัฐ                  เงินเดือน
# 33861  มหาวิทยาลัยมหิดล  แผนงานบุคลากรภาครัฐ               ค่าจ้างประจำ
# 33862  มหาวิทยาลัยมหิดล  แผนงานบุคลากรภาครัฐ            ค่าจ้างชั่วคราว
# 33863  มหาวิทยาลัยมหิดล  แผนงานบุคลากรภาครัฐ  ค่าจ้างพนักงานมหาวิทยาลัย
# 33864  มหาวิทยาลัยมหิดล  แผนงานบุคลากรภาครัฐ        ค่าใช้จ่ายดำเนินงาน
#
#        NUMBER_AMOUNT
# 33860      325801400
# 33861      128738200
# 33862       37316700
# 33863     9937299500
# 33864       97672800

# %%
plt.figure(figsize=(8, 6))
plt.pie(filtered_df3['NUMBER_AMOUNT'], labels=filtered_df3['ITEM_DESCRIPTION'], autopct='%1.1f%%', startangle=140)
plt.title('Budget Plan Distribution HC')
plt.axis('equal')
plt.show()  # Display the pie chart
